# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# %%
# File to Load
input_file_path = "Resources/purchase_data.csv"

# %%
# Read Purchasing File and store into Pandas data frame
game_data_df = pd.read_csv(input_file_path)

# Print Data frame
game_data_df

# Output: 780 rows and 7 columns
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male      101
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# 4                                         Fury   1.44
# ..                                         ...    ...
# 775                                       Wolf   3.54
# 776                           Exiled Doomblade   1.63
# 777      Celeste, Incarnation of the Corrupted   3.46
# 778                               Final Critic   4.19
# 779                                       Dawn   4.60
#
# [780 rows x 7 columns]

# %%
# Remove rows with missing data in any column 
clean_game_data_df = game_data_df.dropna(how='any')
clean_game_data_df

# Output: 780 rows and 7 columns - Cleaning not required
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male      101
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# 4                                         Fury   1.44
# ..                                         ...    ...
# 775                                       Wolf   3.54
# 776                           Exiled Doomblade   1.63
# 777      Celeste, Incarnation of the Corrupted   3.46
# 778                               Final Critic   4.19
# 779                                       Dawn   4.60
#
# [780 rows x 7 columns]

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
# Calculate total number of "unique" players by using function "value counts"
total_players = len(game_data_df["SN"].value_counts())
total_players
# Out:
# 576

# %%
# Create a dataframe for the player_count
player_count_df = pd.DataFrame({"Total Players": [total_players]})
player_count_df
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Calculate unique items using function "unique"
unique_items = len(game_data_df["Item ID"].unique())
unique_items
# Out:
# 183

# %%
# Calculate average price using function "mean" 
average_price = game_data_df["Price"].mean()
average_price
# Out:
# 3.0509871794871795

# %%
# Calculate total number of purchases using function "count"
total_purchases = game_data_df["Price"].count()
total_purchases
# Out:
# 780

# %%
# Calculate total revenue using function "sum" 
total_revenue = game_data_df["Price"].sum()
total_revenue
# Out:
# 2379.77

# %%
# Create the summary data series
summary = [{"Number of Unique Items": unique_items,
              "Average Price": average_price,
              "Number of Purchases": total_purchases,
              "Total Revenue": total_revenue}]

# Create a dataframe for the summary table 
summary_df = pd.DataFrame(summary)

# Display the summary table with formatting for average price and total revenue
summary_df.style.format({"Average Price": "${:,.2f}",
                         "Total Revenue": "${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_c831afec_707e_11ea_9834_3cf01176596b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Unique Items</th>        <th class="col_heading level0 col1" >Average Price</th>        <th class="col_heading level0 col2" >Number of Purchases</th>        <th class="col_heading level0 col3" >Total Revenue</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c831afec_707e_11ea_9834_3cf01176596blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c831afec_707e_11ea_9834_3cf01176596brow0_col0" class="data row0 col0" >183</td>
#                         <td id="T_c831afec_707e_11ea_9834_3cf01176596brow0_col1" class="data row0 col1" >$3.05</td>
#                         <td id="T_c831afec_707e_11ea_9834_3cf01176596brow0_col2" class="data row0 col2" >780</td>
#                         <td id="T_c831afec_707e_11ea_9834_3cf01176596brow0_col3" class="data row0 col3" >$2,379.77</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
# Calculate gender count (nunique gives the count of non-NA cells)
gender_count = game_data_df.groupby("Gender")["SN"].nunique()
gender_count
# Out:
# Gender
# Female                    81
# Male                     484
# Other / Non-Disclosed     11
# Name: SN, dtype: int64

# %%
# Calculate players by gender - 
players_by_gender = game_data_df["Gender"].value_counts()
players_by_gender
# Out:
# Male                     652
# Female                   113
# Other / Non-Disclosed     15
# Name: Gender, dtype: int64

# %%
# Calculate total number of players
players_total = game_data_df["Gender"].count()
players_total
# Out:
# 780

# %%
# Calculate the percentage of each gender
gender_percent = (gender_count/players_total)*100
gender_percent
# Out:
# Gender
# Female                   10.384615
# Male                     62.051282
# Other / Non-Disclosed     1.410256
# Name: SN, dtype: float64

# %%
# Create Gender demographics summary Dataframe
gender_demographics_df= pd.DataFrame({"Total Count": gender_count, 
                                    "Percentage of Players": gender_percent})

# Sort values by descending order of count
gender_demographics_df = gender_demographics_df.sort_values(by = 'Total Count', ascending= False)

# Display the Gender demographics summary with formatting for Percentage of players
gender_demographics_df.style.format ({"Percentage of Players": "{:,.2f}%"})
# Out:
# <style  type="text/css" >
# </style><table id="T_dc2b7608_707e_11ea_9c86_3cf01176596b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dc2b7608_707e_11ea_9c86_3cf01176596blevel0_row0" class="row_heading level0 row0" >Male</th>
#                         <td id="T_dc2b7608_707e_11ea_9c86_3cf01176596brow0_col0" class="data row0 col0" >484</td>
#                         <td id="T_dc2b7608_707e_11ea_9c86_3cf01176596brow0_col1" class="data row0 col1" >62.05%</td>
#             </tr>
#             <tr>
#                         <th id="T_dc2b7608_707e_11ea_9c86_3cf01176596blevel0_row1" class="row_heading level0 row1" >Female</th>
#                         <td id="T_dc2b7608_707e_11ea_9c86_3cf01176596brow1_col0" class="data row1 col0" >81</td>
#                         <td id="T_dc2b7608_707e_11ea_9c86_3cf01176596brow1_col1" class="data row1 col1" >10.38%</td>
#             </tr>
#             <tr>
#                         <th id="T_dc2b7608_707e_11ea_9c86_3cf01176596blevel0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#                         <td id="T_dc2b7608_707e_11ea_9c86_3cf01176596brow2_col0" class="data row2 col0" >11</td>
#                         <td id="T_dc2b7608_707e_11ea_9c86_3cf01176596brow2_col1" class="data row2 col1" >1.41%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Total number of purchases grouped by gender
purchase_count_by_gender = game_data_df.groupby("Gender")["SN"].nunique()
purchase_count_by_gender
# Out:
# Gender
# Female                    81
# Male                     484
# Other / Non-Disclosed     11
# Name: SN, dtype: int64

# %%
# Calculate average price of items by gender
avg_price_by_gender = game_data_df.groupby("Gender")["Price"].mean()
avg_price_by_gender.round(2)
# Out:
# Gender
# Female                   3.20
# Male                     3.02
# Other / Non-Disclosed    3.35
# Name: Price, dtype: float64

# %%
# Calculate total purchase value by gender
total_purchase_value_by_gender = game_data_df.groupby("Gender")["Price"].sum()
total_purchase_value_by_gender.round(2)
# Out:
# Gender
# Female                    361.94
# Male                     1967.64
# Other / Non-Disclosed      50.19
# Name: Price, dtype: float64

# %%
# Calculate average total purchase per person by gender
avg_total_price_per_person_by_gender = total_purchase_value_by_gender/purchase_count_by_gender
avg_total_price_per_person_by_gender.round(2)
# Out:
# Gender
# Female                   4.47
# Male                     4.07
# Other / Non-Disclosed    4.56
# dtype: float64

# %%
# Create the summary dataframe
purchasing_analysis_by_gender_df = pd.DataFrame({"Purchase Count": purchase_count_by_gender, 
                                    "Average Purchase Price": avg_price_by_gender,
                                    "Total Purchase Price": total_purchase_value_by_gender,
                                    "Average Total Purchase Per Person": avg_total_price_per_person_by_gender})
# Sort values by Purchase count
purchasing_analysis_by_gender_df = purchasing_analysis_by_gender_df.sort_values(by='Purchase Count', ascending=False)


# Display the summary dataframe with formatting
purchasing_analysis_by_gender_df.style.format({"Average Purchase Price": "${:,.2f}",
                                "Total Purchase Price": "${:,.2f}",
                                "Average Total Purchase Per Person": "${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_12da44ba_707f_11ea_9262_3cf01176596b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Price</th>        <th class="col_heading level0 col3" >Average Total Purchase Per Person</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_12da44ba_707f_11ea_9262_3cf01176596blevel0_row0" class="row_heading level0 row0" >Male</th>
#                         <td id="T_12da44ba_707f_11ea_9262_3cf01176596brow0_col0" class="data row0 col0" >484</td>
#                         <td id="T_12da44ba_707f_11ea_9262_3cf01176596brow0_col1" class="data row0 col1" >$3.02</td>
#                         <td id="T_12da44ba_707f_11ea_9262_3cf01176596brow0_col2" class="data row0 col2" >$1,967.64</td>
#                         <td id="T_12da44ba_707f_11ea_9262_3cf01176596brow0_col3" class="data row0 col3" >$4.07</td>
#             </tr>
#             <tr>
#                         <th id="T_12da44ba_707f_11ea_9262_3cf01176596blevel0_row1" class="row_heading level0 row1" >Female</th>
#                         <td id="T_12da44ba_707f_11ea_9262_3cf01176596brow1_col0" class="data row1 col0" >81</td>
#                         <td id="T_12da44ba_707f_11ea_9262_3cf01176596brow1_col1" class="data row1 col1" >$3.20</td>
#                         <td id="T_12da44ba_707f_11ea_9262_3cf01176596brow1_col2" class="data row1 col2" >$361.94</td>
#                         <td id="T_12da44ba_707f_11ea_9262_3cf01176596brow1_col3" class="data row1 col3" >$4.47</td>
#             </tr>
#             <tr>
#                         <th id="T_12da44ba_707f_11ea_9262_3cf01176596blevel0_row2" class="row_heading level0 row2" >Other / Non-Disclosed</th>
#                         <td id="T_12da44ba_707f_11ea_9262_3cf01176596brow2_col0" class="data row2 col0" >11</td>
#                         <td id="T_12da44ba_707f_11ea_9262_3cf01176596brow2_col1" class="data row2 col1" >$3.35</td>
#                         <td id="T_12da44ba_707f_11ea_9262_3cf01176596brow2_col2" class="data row2 col2" >$50.19</td>
#                         <td id="T_12da44ba_707f_11ea_9262_3cf01176596brow2_col3" class="data row2 col3" >$4.56</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# Create bins for ages
age_bins = [0, 9, 14, 19, 24, 29, 34, 39, 100]
age_group_names = ['<10', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40+']

# %%
# Categorize players using age bins using pd.cut() and 
# Place the new data series into a new column named "Age Group"
game_data_df ["Age Group"] = pd.cut(game_data_df["Age"], age_bins, include_lowest = False, labels=age_group_names)
game_data_df ["Age Group"]
# Out:
# 0      20-24
# 1        40+
# 2      20-24
# 3      20-24
# 4      20-24
#        ...
# 775    20-24
# 776    20-24
# 777    20-24
# 778      <10
# 779    20-24
# Name: Age Group, Length: 780, dtype: category
# Categories (8, object): [<10 < 10-14 < 15-19 < 20-24 < 25-29 < 30-34 < 35-39 < 40+]

# %%
# Display the Age Range column for players categorized by age groups 
game_data_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price Age Group
# 0  Extraction, Quickblade Of Trembling Hands   3.53     20-24
# 1                          Frenzied Scimitar   1.56       40+
# 2                               Final Critic   4.88     20-24
# 3                                Blindscythe   3.27     20-24
# 4                                       Fury   1.44     20-24

# %%
# Create a GroupBy object based on the age groups - find amount of unique players making purchases
player_count_by_age_group = game_data_df.groupby("Age Group")["SN"].nunique()
player_count_by_age_group
# Out:
# Age Group
# <10       17
# 10-14     22
# 15-19    107
# 20-24    258
# 25-29     77
# 30-34     52
# 35-39     31
# 40+       12
# Name: SN, dtype: int64

# %%
# Purchase count by age group
purchase_count_by_age_group = game_data_df.groupby("Age Group")["SN"].count()
purchase_count_by_age_group
# Out:
# Age Group
# <10       23
# 10-14     28
# 15-19    136
# 20-24    365
# 25-29    101
# 30-34     73
# 35-39     41
# 40+       13
# Name: SN, dtype: int64

# %%
# Calculate the percentages by age group
percent_players_by_age_group = player_count_by_age_group/total_players*100
percent_players_by_age_group
# Out:
# Age Group
# <10       2.951389
# 10-14     3.819444
# 15-19    18.576389
# 20-24    44.791667
# 25-29    13.368056
# 30-34     9.027778
# 35-39     5.381944
# 40+       2.083333
# Name: SN, dtype: float64

# %%
# Create a summary data frame to hold the age demographics
age_demographics_df = pd.DataFrame({"Total Count": player_count_by_age_group,
                                    "Percentage of Players": percent_players_by_age_group})

# Display the Age Demographics table - using the sort_index function
age_demographics_df.style.format({"Percentage of Players": "{:,.2f}%"})
# Out:
# <style  type="text/css" >
# </style><table id="T_43e5881c_707f_11ea_91da_3cf01176596b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr>    <tr>        <th class="index_name level0" >Age Group</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_43e5881c_707f_11ea_91da_3cf01176596blevel0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_43e5881c_707f_11ea_91da_3cf01176596brow0_col0" class="data row0 col0" >17</td>
#                         <td id="T_43e5881c_707f_11ea_91da_3cf01176596brow0_col1" class="data row0 col1" >2.95%</td>
#             </tr>
#             <tr>
#                         <th id="T_43e5881c_707f_11ea_91da_3cf01176596blevel0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_43e5881c_707f_11ea_91da_3cf01176596brow1_col0" class="data row1 col0" >22</td>
#                         <td id="T_43e5881c_707f_11ea_91da_3cf01176596brow1_col1" class="data row1 col1" >3.82%</td>
#             </tr>
#             <tr>
#                         <th id="T_43e5881c_707f_11ea_91da_3cf01176596blevel0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_43e5881c_707f_11ea_91da_3cf01176596brow2_col0" class="data row2 col0" >107</td>
#                         <td id="T_43e5881c_707f_11ea_91da_3cf01176596brow2_col1" class="data row2 col1" >18.58%</td>
#             </tr>
#             <tr>
#                         <th id="T_43e5881c_707f_11ea_91da_3cf01176596blevel0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_43e5881c_707f_11ea_91da_3cf01176596brow3_col0" class="data row3 col0" >258</td>
#                         <td id="T_43e5881c_707f_11ea_91da_3cf01176596brow3_col1" class="data row3 col1" >44.79%</td>
#             </tr>
#             <tr>
#                         <th id="T_43e5881c_707f_11ea_91da_3cf01176596blevel0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_43e5881c_707f_11ea_91da_3cf01176596brow4_col0" class="data row4 col0" >77</td>
#                         <td id="T_43e5881c_707f_11ea_91da_3cf01176596brow4_col1" class="data row4 col1" >13.37%</td>
#             </tr>
#             <tr>
#                         <th id="T_43e5881c_707f_11ea_91da_3cf01176596blevel0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_43e5881c_707f_11ea_91da_3cf01176596brow5_col0" class="data row5 col0" >52</td>
#                         <td id="T_43e5881c_707f_11ea_91da_3cf01176596brow5_col1" class="data row5 col1" >9.03%</td>
#             </tr>
#             <tr>
#                         <th id="T_43e5881c_707f_11ea_91da_3cf01176596blevel0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_43e5881c_707f_11ea_91da_3cf01176596brow6_col0" class="data row6 col0" >31</td>
#                         <td id="T_43e5881c_707f_11ea_91da_3cf01176596brow6_col1" class="data row6 col1" >5.38%</td>
#             </tr>
#             <tr>
#                         <th id="T_43e5881c_707f_11ea_91da_3cf01176596blevel0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_43e5881c_707f_11ea_91da_3cf01176596brow7_col0" class="data row7 col0" >12</td>
#                         <td id="T_43e5881c_707f_11ea_91da_3cf01176596brow7_col1" class="data row7 col1" >2.08%</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
# Displaying the main DF for reference
game_data_df
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male      101
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price Age Group
# 0    Extraction, Quickblade Of Trembling Hands   3.53     20-24
# 1                            Frenzied Scimitar   1.56       40+
# 2                                 Final Critic   4.88     20-24
# 3                                  Blindscythe   3.27     20-24
# 4                                         Fury   1.44     20-24
# ..                                         ...    ...       ...
# 775                                       Wolf   3.54     20-24
# 776                           Exiled Doomblade   1.63     20-24
# 777      Celeste, Incarnation of the Corrupted   3.46     20-24
# 778                               Final Critic   4.19       <10
# 779                                       Dawn   4.60     20-24
#
# [780 rows x 8 columns]

# %%
# Total number of players grouped by age group
player_count_by_age = game_data_df.groupby("Age Group")["SN"].nunique()
player_count_by_age
# Out:
# Age Group
# <10       17
# 10-14     22
# 15-19    107
# 20-24    258
# 25-29     77
# 30-34     52
# 35-39     31
# 40+       12
# Name: SN, dtype: int64

# %%
# Total number of purchases grouped by age
purchase_count_by_age = game_data_df.groupby("Age Group")["Item ID"].count()
purchase_count_by_age
# Out:
# Age Group
# <10       23
# 10-14     28
# 15-19    136
# 20-24    365
# 25-29    101
# 30-34     73
# 35-39     41
# 40+       13
# Name: Item ID, dtype: int64

# %%
# Calculate average price of items by age group
avg_price_by_age = game_data_df.groupby("Age Group")["Price"].mean()
avg_price_by_age.round(2)
# Out:
# Age Group
# <10      3.35
# 10-14    2.96
# 15-19    3.04
# 20-24    3.05
# 25-29    2.90
# 30-34    2.93
# 35-39    3.60
# 40+      2.94
# Name: Price, dtype: float64

# %%
# Calculate total purchase value by age group
total_purchase_value_by_age = game_data_df.groupby("Age Group")["Price"].sum()
total_purchase_value_by_age.round(2)
# Out:
# Age Group
# <10        77.13
# 10-14      82.78
# 15-19     412.89
# 20-24    1114.06
# 25-29     293.00
# 30-34     214.00
# 35-39     147.67
# 40+        38.24
# Name: Price, dtype: float64

# %%
# Calculate average total purchase per person by age group
avg_total_price_per_person_by_age = total_purchase_value_by_age/player_count_by_age
avg_total_price_per_person_by_age.round(2)
# Out:
# Age Group
# <10      4.54
# 10-14    3.76
# 15-19    3.86
# 20-24    4.32
# 25-29    3.81
# 30-34    4.12
# 35-39    4.76
# 40+      3.19
# dtype: float64

# %%
# Create the summary dataframe
purchasing_analysis_by_age_df = pd.DataFrame({"Purchase Count": purchase_count_by_age, 
                                    "Average Purchase Price": avg_price_by_age,
                                    "Total Purchase Price": total_purchase_value_by_age,
                                    "Average Total Purchase Per Person": avg_total_price_per_person_by_age})
# Display the summary dataframe with formatting
purchasing_analysis_by_age_df.style.format({"Average Purchase Price": "${:,.2f}",
                                "Total Purchase Price": "${:,.2f}",
                                "Average Total Purchase Per Person": "${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_93e380a8_7080_11ea_ab29_3cf01176596b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Price</th>        <th class="col_heading level0 col3" >Average Total Purchase Per Person</th>    </tr>    <tr>        <th class="index_name level0" >Age Group</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_93e380a8_7080_11ea_ab29_3cf01176596blevel0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow0_col0" class="data row0 col0" >23</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow0_col1" class="data row0 col1" >$3.35</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow0_col2" class="data row0 col2" >$77.13</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow0_col3" class="data row0 col3" >$4.54</td>
#             </tr>
#             <tr>
#                         <th id="T_93e380a8_7080_11ea_ab29_3cf01176596blevel0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow1_col0" class="data row1 col0" >28</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow1_col1" class="data row1 col1" >$2.96</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow1_col2" class="data row1 col2" >$82.78</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow1_col3" class="data row1 col3" >$3.76</td>
#             </tr>
#             <tr>
#                         <th id="T_93e380a8_7080_11ea_ab29_3cf01176596blevel0_row2" class="row_heading level0 row2" >15-19</th>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow2_col0" class="data row2 col0" >136</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow2_col1" class="data row2 col1" >$3.04</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow2_col2" class="data row2 col2" >$412.89</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow2_col3" class="data row2 col3" >$3.86</td>
#             </tr>
#             <tr>
#                         <th id="T_93e380a8_7080_11ea_ab29_3cf01176596blevel0_row3" class="row_heading level0 row3" >20-24</th>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow3_col0" class="data row3 col0" >365</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow3_col1" class="data row3 col1" >$3.05</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow3_col2" class="data row3 col2" >$1,114.06</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow3_col3" class="data row3 col3" >$4.32</td>
#             </tr>
#             <tr>
#                         <th id="T_93e380a8_7080_11ea_ab29_3cf01176596blevel0_row4" class="row_heading level0 row4" >25-29</th>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow4_col0" class="data row4 col0" >101</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow4_col1" class="data row4 col1" >$2.90</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow4_col2" class="data row4 col2" >$293.00</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow4_col3" class="data row4 col3" >$3.81</td>
#             </tr>
#             <tr>
#                         <th id="T_93e380a8_7080_11ea_ab29_3cf01176596blevel0_row5" class="row_heading level0 row5" >30-34</th>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow5_col0" class="data row5 col0" >73</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow5_col1" class="data row5 col1" >$2.93</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow5_col2" class="data row5 col2" >$214.00</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow5_col3" class="data row5 col3" >$4.12</td>
#             </tr>
#             <tr>
#                         <th id="T_93e380a8_7080_11ea_ab29_3cf01176596blevel0_row6" class="row_heading level0 row6" >35-39</th>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow6_col0" class="data row6 col0" >41</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow6_col1" class="data row6 col1" >$3.60</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow6_col2" class="data row6 col2" >$147.67</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow6_col3" class="data row6 col3" >$4.76</td>
#             </tr>
#             <tr>
#                         <th id="T_93e380a8_7080_11ea_ab29_3cf01176596blevel0_row7" class="row_heading level0 row7" >40+</th>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow7_col0" class="data row7 col0" >13</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow7_col1" class="data row7 col1" >$2.94</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow7_col2" class="data row7 col2" >$38.24</td>
#                         <td id="T_93e380a8_7080_11ea_ab29_3cf01176596brow7_col3" class="data row7 col3" >$3.19</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Calculate the Purchase count per player
purchase_count_per_player = game_data_df.groupby("SN")["SN"].count()
purchase_count_per_player
# Out:
# SN
# Adairialis76     1
# Adastirin33      1
# Aeda94           1
# Aela59           1
# Aelaria33        1
#                 ..
# Yathecal82       3
# Yathedeu43       2
# Yoishirrala98    1
# Zhisrisu83       2
# Zontibe81        3
# Name: SN, Length: 576, dtype: int64

# %%
# Calculate the average price per player
average_price_per_player = game_data_df.groupby("SN")["Price"].mean()
average_price_per_player
# Out:
# SN
# Adairialis76     2.280000
# Adastirin33      4.480000
# Aeda94           4.910000
# Aela59           4.320000
# Aelaria33        1.790000
#                    ...
# Yathecal82       2.073333
# Yathedeu43       3.010000
# Yoishirrala98    4.580000
# Zhisrisu83       3.945000
# Zontibe81        2.676667
# Name: Price, Length: 576, dtype: float64

# %%
# Calculate the total purchase value per player
total_purchase_value_per_player = game_data_df.groupby("SN")["Price"].sum()
total_purchase_value_per_player
# Out:
# SN
# Adairialis76     2.28
# Adastirin33      4.48
# Aeda94           4.91
# Aela59           4.32
# Aelaria33        1.79
#                  ...
# Yathecal82       6.22
# Yathedeu43       6.02
# Yoishirrala98    4.58
# Zhisrisu83       7.89
# Zontibe81        8.03
# Name: Price, Length: 576, dtype: float64

# %%
# Create the summary dataframe
summary_per_player_df = pd.DataFrame({"Purchase Count":purchase_count_per_player,
                                   "Average Purchase Price": average_price_per_player,
                                   "Total Purchase Value": total_purchase_value_per_player})

# Display the summary dataframe with formatting
summary_per_player_df.style.format({"Average Purchase Price": "${:,.2f}", 
                                                            "Total Purchase Value": "${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_14b99714_7082_11ea_9af7_3cf01176596b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >SN</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_14b99714_7082_11ea_9af7_3cf01176596blevel0_row0" class="row_heading level0 row0" >Adairialis76</th>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow0_col0" class="data row0 col0" >1</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow0_col1" class="data row0 col1" >$2.28</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow0_col2" class="data row0 col2" >$2.28</td>
#             </tr>
#             <tr>
#                         <th id="T_14b99714_7082_11ea_9af7_3cf01176596blevel0_row1" class="row_heading level0 row1" >Adastirin33</th>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow1_col0" class="data row1 col0" >1</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow1_col1" class="data row1 col1" >$4.48</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow1_col2" class="data row1 col2" >$4.48</td>
#             </tr>
#             <tr>
#                         <th id="T_14b99714_7082_11ea_9af7_3cf01176596blevel0_row2" class="row_heading level0 row2" >Aeda94</th>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow2_col0" class="data row2 col0" >1</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow2_col1" class="data row2 col1" >$4.91</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow2_col2" class="data row2 col2" >$4.91</td>
#             </tr>
#             <tr>
#                         <th id="T_14b99714_7082_11ea_9af7_3cf01176596blevel0_row3" class="row_heading level0 row3" >Aela59</th>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow3_col0" class="data row3 col0" >1</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow3_col1" class="data row3 col1" >$4.32</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow3_col2" class="data row3 col2" >$4.32</td>
#             </tr>
#             <tr>
#                         <th id="T_14b99714_7082_11ea_9af7_3cf01176596blevel0_row4" class="row_heading level0 row4" >Aelaria33</th>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow4_col0" class="data row4 col0" >1</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow4_col1" class="data row4 col1" >$1.79</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow4_col2" class="data row4 col2" >$1.79</td>
#             </tr>
#             <tr>
#                         <th id="T_14b99714_7082_11ea_9af7_3cf01176596blevel0_row5" class="row_heading level0 row5" >Aelastirin39</th>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow5_col0" class="data row5 col0" >2</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow5_col1" class="data row5 col1" >$3.64</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow5_col2" class="data row5 col2" >$7.29</td>
#             </tr>
#             <tr>
#                         <th id="T_14b99714_7082_11ea_9af7_3cf01176596blevel0_row6" class="row_heading level0 row6" >Aelidru27</th>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow6_col0" class="data row6 col0" >1</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow6_col1" class="data row6 col1" >$1.09</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow6_col2" class="data row6 col2" >$1.09</td>
#             </tr>
#             <tr>
#                         <th id="T_14b99714_7082_11ea_9af7_3cf01176596blevel0_row7" class="row_heading level0 row7" >Aelin32</th>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow7_col0" class="data row7 col0" >3</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow7_col1" class="data row7 col1" >$2.99</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow7_col2" class="data row7 col2" >$8.98</td>
#             </tr>
#             <tr>
#                         <th id="T_14b99714_7082_11ea_9af7_3cf01176596blevel0_row8" class="row_heading level0 row8" >Aelly27</th>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow8_col0" class="data row8 col0" >2</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow8_col1" class="data row8 col1" >$3.39</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow8_col2" class="data row8 col2" >$6.79</td>
#             </tr>
#             <tr>
#                         <th id="T_14b99714_7082_11ea_9af7_3cf01176596blevel0_row9" class="row_heading level0 row9" >Aellynun67</th>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow9_col0" class="data row9 col0" >1</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow9_col1" class="data row9 col1" >$3.74</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow9_col2" class="data row9 col2" >$3.74</td>
#             </tr>
#             <tr>
#                         <th id="T_14b99714_7082_11ea_9af7_3cf01176596blevel0_row10" class="row_heading level0 row10" >Aellyria80</th>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow10_col0" class="data row10 col0" >1</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow10_col1" class="data row10 col1" >$3.08</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow10_col2" class="data row10 col2" >$3.08</td>
#             </tr>
#             <tr>
#                         <th id="T_14b99714_7082_11ea_9af7_3cf01176596blevel0_row11" class="row_heading level0 row11" >Aelollo59</th>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow11_col0" class="data row11 col0" >2</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow11_col1" class="data row11 col1" >$2.82</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow11_col2" class="data row11 col2" >$5.63</td>
#             </tr>
#             <tr>
#                         <th id="T_14b99714_7082_11ea_9af7_3cf01176596blevel0_row12" class="row_heading level0 row12" >Aenarap34</th>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow12_col0" class="data row12 col0" >1</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow12_col1" class="data row12 col1" >$2.96</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow12_col2" class="data row12 col2" >$2.96</td>
#             </tr>
#             <tr>
#                         <th id="T_14b99714_7082_11ea_9af7_3cf01176596blevel0_row13" class="row_heading level0 row13" >Aeral43</th>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow13_col0" class="data row13 col0" >1</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow13_col1" class="data row13 col1" >$4.40</td>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow13_col2" class="data row13 col2" >$4.40</td>
#             </tr>
#             <tr>
#                         <th id="T_14b99714_7082_11ea_9af7_3cf01176596blevel0_row14" class="row_heading level0 row14" >Aeral68</th>
#                         <td id="T_14b99714_7082_11ea_9af7_3cf01176596brow14_col0" class="data row14 col0" >1</td>
#                         <td id="T_

# %%
# Sort table to show the top five spenders.
top_five_spenders_df = summary_per_player_df.sort_values("Total Purchase Value", ascending=False)
top_five_spenders_df.style.format({"Average Purchase Price": "${:,.2f}", 
                                "Total Purchase Value": "${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_5b29979e_7082_11ea_a9dd_3cf01176596b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >SN</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5b29979e_7082_11ea_a9dd_3cf01176596blevel0_row0" class="row_heading level0 row0" >Lisosia93</th>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow0_col0" class="data row0 col0" >5</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow0_col1" class="data row0 col1" >$3.79</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow0_col2" class="data row0 col2" >$18.96</td>
#             </tr>
#             <tr>
#                         <th id="T_5b29979e_7082_11ea_a9dd_3cf01176596blevel0_row1" class="row_heading level0 row1" >Idastidru52</th>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow1_col0" class="data row1 col0" >4</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow1_col1" class="data row1 col1" >$3.86</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow1_col2" class="data row1 col2" >$15.45</td>
#             </tr>
#             <tr>
#                         <th id="T_5b29979e_7082_11ea_a9dd_3cf01176596blevel0_row2" class="row_heading level0 row2" >Chamjask73</th>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow2_col0" class="data row2 col0" >3</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow2_col1" class="data row2 col1" >$4.61</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow2_col2" class="data row2 col2" >$13.83</td>
#             </tr>
#             <tr>
#                         <th id="T_5b29979e_7082_11ea_a9dd_3cf01176596blevel0_row3" class="row_heading level0 row3" >Iral74</th>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow3_col0" class="data row3 col0" >4</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow3_col1" class="data row3 col1" >$3.40</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow3_col2" class="data row3 col2" >$13.62</td>
#             </tr>
#             <tr>
#                         <th id="T_5b29979e_7082_11ea_a9dd_3cf01176596blevel0_row4" class="row_heading level0 row4" >Iskadarya95</th>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow4_col0" class="data row4 col0" >3</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow4_col1" class="data row4 col1" >$4.37</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow4_col2" class="data row4 col2" >$13.10</td>
#             </tr>
#             <tr>
#                         <th id="T_5b29979e_7082_11ea_a9dd_3cf01176596blevel0_row5" class="row_heading level0 row5" >Ilarin91</th>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow5_col0" class="data row5 col0" >3</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow5_col1" class="data row5 col1" >$4.23</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow5_col2" class="data row5 col2" >$12.70</td>
#             </tr>
#             <tr>
#                         <th id="T_5b29979e_7082_11ea_a9dd_3cf01176596blevel0_row6" class="row_heading level0 row6" >Ialallo29</th>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow6_col0" class="data row6 col0" >3</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow6_col1" class="data row6 col1" >$3.95</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow6_col2" class="data row6 col2" >$11.84</td>
#             </tr>
#             <tr>
#                         <th id="T_5b29979e_7082_11ea_a9dd_3cf01176596blevel0_row7" class="row_heading level0 row7" >Tyidaim51</th>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow7_col0" class="data row7 col0" >3</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow7_col1" class="data row7 col1" >$3.94</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow7_col2" class="data row7 col2" >$11.83</td>
#             </tr>
#             <tr>
#                         <th id="T_5b29979e_7082_11ea_a9dd_3cf01176596blevel0_row8" class="row_heading level0 row8" >Lassilsala30</th>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow8_col0" class="data row8 col0" >3</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow8_col1" class="data row8 col1" >$3.84</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow8_col2" class="data row8 col2" >$11.51</td>
#             </tr>
#             <tr>
#                         <th id="T_5b29979e_7082_11ea_a9dd_3cf01176596blevel0_row9" class="row_heading level0 row9" >Chadolyla44</th>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow9_col0" class="data row9 col0" >3</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow9_col1" class="data row9 col1" >$3.82</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow9_col2" class="data row9 col2" >$11.46</td>
#             </tr>
#             <tr>
#                         <th id="T_5b29979e_7082_11ea_a9dd_3cf01176596blevel0_row10" class="row_heading level0 row10" >Iri67</th>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow10_col0" class="data row10 col0" >3</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow10_col1" class="data row10 col1" >$3.79</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow10_col2" class="data row10 col2" >$11.37</td>
#             </tr>
#             <tr>
#                         <th id="T_5b29979e_7082_11ea_a9dd_3cf01176596blevel0_row11" class="row_heading level0 row11" >Inguron55</th>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow11_col0" class="data row11 col0" >3</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow11_col1" class="data row11 col1" >$3.70</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow11_col2" class="data row11 col2" >$11.11</td>
#             </tr>
#             <tr>
#                         <th id="T_5b29979e_7082_11ea_a9dd_3cf01176596blevel0_row12" class="row_heading level0 row12" >Siallylis44</th>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow12_col0" class="data row12 col0" >3</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow12_col1" class="data row12 col1" >$3.46</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow12_col2" class="data row12 col2" >$10.37</td>
#             </tr>
#             <tr>
#                         <th id="T_5b29979e_7082_11ea_a9dd_3cf01176596blevel0_row13" class="row_heading level0 row13" >Saistyphos30</th>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow13_col0" class="data row13 col0" >3</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow13_col1" class="data row13 col1" >$3.44</td>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow13_col2" class="data row13 col2" >$10.33</td>
#             </tr>
#             <tr>
#                         <th id="T_5b29979e_7082_11ea_a9dd_3cf01176596blevel0_row14" class="row_heading level0 row14" >Phyali88</th>
#                         <td id="T_5b29979e_7082_11ea_a9dd_3cf01176596brow14_col0" class="data row14 col0" >3</td>

# %% [markdown]
# ## Most Popular Items

# %%
# Display the top five spenders
top_five_spenders_df.head()
# Out:
#              Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Lisosia93                 5                3.792000                 18.96
# Idastidru52               4                3.862500                 15.45
# Chamjask73                3                4.610000                 13.83
# Iral74                    4                3.405000                 13.62
# Iskadarya95               3                4.366667                 13.10

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
# Calculate purchase count
total_purchase_count_df = game_data_df.groupby(["Item ID", "Item Name"])["SN"].count()
total_purchase_count_df
# Out:
# Item ID  Item Name
# 0        Splinter                           4
# 1        Crucifer                           3
# 2        Verdict                            6
# 3        Phantomlight                       6
# 4        Bloodlord's Fetish                 5
#                                            ..
# 179      Wolf, Promise of the Moonwalker    6
# 180      Stormcaller                        1
# 181      Reaper's Toll                      5
# 182      Toothpick                          3
# 183      Dragon's Greatsword                3
# Name: SN, Length: 183, dtype: int64

# %%
# Calculate average purchase price
avg_purchase_price_df = game_data_df.groupby(["Item ID", "Item Name"])["Price"].mean()
avg_purchase_price_df
# Out:
# Item ID  Item Name
# 0        Splinter                           1.28
# 1        Crucifer                           3.26
# 2        Verdict                            2.48
# 3        Phantomlight                       2.49
# 4        Bloodlord's Fetish                 1.70
#                                             ...
# 179      Wolf, Promise of the Moonwalker    4.48
# 180      Stormcaller                        3.36
# 181      Reaper's Toll                      1.66
# 182      Toothpick                          4.03
# 183      Dragon's Greatsword                1.09
# Name: Price, Length: 183, dtype: float64

# %%
# Calculate the Total purchase value
total_purchase_value_df = game_data_df.groupby(["Item ID", "Item Name"])["Price"].sum()
total_purchase_value_df
# Out:
# Item ID  Item Name
# 0        Splinter                            5.12
# 1        Crucifer                            9.78
# 2        Verdict                            14.88
# 3        Phantomlight                       14.94
# 4        Bloodlord's Fetish                  8.50
#                                             ...
# 179      Wolf, Promise of the Moonwalker    26.88
# 180      Stormcaller                         3.36
# 181      Reaper's Toll                       8.30
# 182      Toothpick                          12.09
# 183      Dragon's Greatsword                 3.27
# Name: Price, Length: 183, dtype: float64

# %%
# Convert to DataFrame
purchasing_analysis_df = pd.DataFrame({"Purchase Count":total_purchase_count_df,
                                   "Item Price":avg_purchase_price_df,
                                   "Total Purchase Value":total_purchase_value_df,})
# Format the dataframe
purchasing_analysis_df.style.format({"Item Price": "${:,.2f}", 
                                "Total Purchase Value": "${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_a39832ba_7082_11ea_9114_3cf01176596b" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel0_row0" class="row_heading level0 row0" >0</th>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel1_row0" class="row_heading level1 row0" >Splinter</th>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow0_col0" class="data row0 col0" >4</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow0_col1" class="data row0 col1" >$1.28</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow0_col2" class="data row0 col2" >$5.12</td>
#             </tr>
#             <tr>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel0_row1" class="row_heading level0 row1" >1</th>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel1_row1" class="row_heading level1 row1" >Crucifer</th>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow1_col0" class="data row1 col0" >3</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow1_col1" class="data row1 col1" >$3.26</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow1_col2" class="data row1 col2" >$9.78</td>
#             </tr>
#             <tr>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel0_row2" class="row_heading level0 row2" >2</th>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel1_row2" class="row_heading level1 row2" >Verdict</th>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow2_col0" class="data row2 col0" >6</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow2_col1" class="data row2 col1" >$2.48</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow2_col2" class="data row2 col2" >$14.88</td>
#             </tr>
#             <tr>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel1_row3" class="row_heading level1 row3" >Phantomlight</th>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow3_col0" class="data row3 col0" >6</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow3_col1" class="data row3 col1" >$2.49</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow3_col2" class="data row3 col2" >$14.94</td>
#             </tr>
#             <tr>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel0_row4" class="row_heading level0 row4" >4</th>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel1_row4" class="row_heading level1 row4" >Bloodlord's Fetish</th>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow4_col0" class="data row4 col0" >5</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow4_col1" class="data row4 col1" >$1.70</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow4_col2" class="data row4 col2" >$8.50</td>
#             </tr>
#             <tr>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel0_row5" class="row_heading level0 row5" >5</th>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel1_row5" class="row_heading level1 row5" >Putrid Fan</th>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow5_col0" class="data row5 col0" >4</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow5_col1" class="data row5 col1" >$4.08</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow5_col2" class="data row5 col2" >$16.32</td>
#             </tr>
#             <tr>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel0_row6" class="row_heading level0 row6" >6</th>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel1_row6" class="row_heading level1 row6" >Rusty Skull</th>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow6_col0" class="data row6 col0" >2</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow6_col1" class="data row6 col1" >$3.70</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow6_col2" class="data row6 col2" >$7.40</td>
#             </tr>
#             <tr>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel0_row7" class="row_heading level0 row7" >7</th>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel1_row7" class="row_heading level1 row7" >Thorn, Satchel of Dark Souls</th>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow7_col0" class="data row7 col0" >7</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow7_col1" class="data row7 col1" >$1.33</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow7_col2" class="data row7 col2" >$9.31</td>
#             </tr>
#             <tr>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel0_row8" class="row_heading level0 row8" >8</th>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel1_row8" class="row_heading level1 row8" >Purgatory, Gem of Regret</th>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow8_col0" class="data row8 col0" >3</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow8_col1" class="data row8 col1" >$3.93</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow8_col2" class="data row8 col2" >$11.79</td>
#             </tr>
#             <tr>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel0_row9" class="row_heading level0 row9" >9</th>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel1_row9" class="row_heading level1 row9" >Thorn, Conqueror of the Corrupted</th>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow9_col0" class="data row9 col0" >4</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow9_col1" class="data row9 col1" >$2.73</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow9_col2" class="data row9 col2" >$10.92</td>
#             </tr>
#             <tr>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel0_row10" class="row_heading level0 row10" >10</th>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel1_row10" class="row_heading level1 row10" >Sleepwalker</th>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow10_col0" class="data row10 col0" >4</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow10_col1" class="data row10 col1" >$1.79</td>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf01176596brow10_col2" class="data row10 col2" >$7.16</td>
#             </tr>
#             <tr>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel0_row11" class="row_heading level0 row11" >11</th>
#                         <th id="T_a39832ba_7082_11ea_9114_3cf01176596blevel1_row11" class="row_heading level1 row11" >Brimstone</th>
#                         <td id="T_a39832ba_7082_11ea_9114_3cf0

# %%
# Sort table to show the five the most popular items.
most_popular_items_df = purchasing_analysis_df.sort_values("Purchase Count", ascending=False)

# Format the dataframe
most_popular_items_df.style.format({"Item Price": "${:,.2f}", 
                                "Total Purchase Value": "${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_a1a7c500_7083_11ea_af51_3cf01176596b" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel0_row0" class="row_heading level0 row0" >178</th>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel1_row0" class="row_heading level1 row0" >Oathbreaker, Last Hope of the Breaking Storm</th>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow0_col0" class="data row0 col0" >12</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow0_col1" class="data row0 col1" >$4.23</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow0_col2" class="data row0 col2" >$50.76</td>
#             </tr>
#             <tr>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel0_row1" class="row_heading level0 row1" >145</th>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel1_row1" class="row_heading level1 row1" >Fiery Glass Crusader</th>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow1_col0" class="data row1 col0" >9</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow1_col1" class="data row1 col1" >$4.58</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow1_col2" class="data row1 col2" >$41.22</td>
#             </tr>
#             <tr>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel0_row2" class="row_heading level0 row2" >108</th>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel1_row2" class="row_heading level1 row2" >Extraction, Quickblade Of Trembling Hands</th>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow2_col0" class="data row2 col0" >9</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow2_col1" class="data row2 col1" >$3.53</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow2_col2" class="data row2 col2" >$31.77</td>
#             </tr>
#             <tr>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel0_row3" class="row_heading level0 row3" >82</th>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel1_row3" class="row_heading level1 row3" >Nirvana</th>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow3_col0" class="data row3 col0" >9</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow3_col1" class="data row3 col1" >$4.90</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow3_col2" class="data row3 col2" >$44.10</td>
#             </tr>
#             <tr>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel0_row4" class="row_heading level0 row4" >19</th>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel1_row4" class="row_heading level1 row4" >Pursuit, Cudgel of Necromancy</th>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow4_col0" class="data row4 col0" >8</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow4_col1" class="data row4 col1" >$1.02</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow4_col2" class="data row4 col2" >$8.16</td>
#             </tr>
#             <tr>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel0_row5" class="row_heading level0 row5" >103</th>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel1_row5" class="row_heading level1 row5" >Singed Scalpel</th>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow5_col0" class="data row5 col0" >8</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow5_col1" class="data row5 col1" >$4.35</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow5_col2" class="data row5 col2" >$34.80</td>
#             </tr>
#             <tr>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel0_row6" class="row_heading level0 row6" >75</th>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel1_row6" class="row_heading level1 row6" >Brutality Ivory Warmace</th>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow6_col0" class="data row6 col0" >8</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow6_col1" class="data row6 col1" >$2.42</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow6_col2" class="data row6 col2" >$19.36</td>
#             </tr>
#             <tr>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel0_row7" class="row_heading level0 row7" >72</th>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel1_row7" class="row_heading level1 row7" >Winter's Bite</th>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow7_col0" class="data row7 col0" >8</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow7_col1" class="data row7 col1" >$3.77</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow7_col2" class="data row7 col2" >$30.16</td>
#             </tr>
#             <tr>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel0_row8" class="row_heading level0 row8" >60</th>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel1_row8" class="row_heading level1 row8" >Wolf</th>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow8_col0" class="data row8 col0" >8</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow8_col1" class="data row8 col1" >$3.54</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow8_col2" class="data row8 col2" >$28.32</td>
#             </tr>
#             <tr>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel0_row9" class="row_heading level0 row9" >59</th>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel1_row9" class="row_heading level1 row9" >Lightning, Etcher of the King</th>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow9_col0" class="data row9 col0" >8</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow9_col1" class="data row9 col1" >$4.23</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow9_col2" class="data row9 col2" >$33.84</td>
#             </tr>
#             <tr>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel0_row10" class="row_heading level0 row10" >37</th>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel1_row10" class="row_heading level1 row10" >Shadow Strike, Glory of Ending Hope</th>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow10_col0" class="data row10 col0" >8</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow10_col1" class="data row10 col1" >$3.16</td>
#                         <td id="T_a1a7c500_7083_11ea_af51_3cf01176596brow10_col2" class="data row10 col2" >$25.28</td>
#             </tr>
#             <tr>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel0_row11" class="row_heading level0 row11" >34</th>
#                         <th id="T_a1a7c500_7083_11ea_af51_3cf01176596blevel1_row11" cl

# %%
most_popular_items_df.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 108     Extraction, Quickblade Of Trembling Hands                  9
# 82      Nirvana                                                    9
# 19      Pursuit, Cudgel of Necromancy                              8
#
#                                                       Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm        4.23
# 145     Fiery Glass Crusader                                4.58
# 108     Extraction, Quickblade Of Trembling Hands           3.53
# 82      Nirvana                                             4.90
# 19      Pursuit, Cudgel of Necromancy                       1.02
#
#                                                       Total Purchase Value
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm                 50.76
# 145     Fiery Glass Crusader                                         41.22
# 108     Extraction, Quickblade Of Trembling Hands                    31.77
# 82      Nirvana                                                      44.10
# 19      Pursuit, Cudgel of Necromancy                                 8.16

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
#  Sort table to show the five the most profitable items.

most_profitable_items_df = purchasing_analysis_df.sort_values("Total Purchase Value", ascending=False)
most_profitable_items_df.style.format({"Item Price": "${:,.2f}", 
                                "Total Purchase Value": "${:,.2f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_f44f5ca4_7083_11ea_83ca_3cf01176596b" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel0_row0" class="row_heading level0 row0" >178</th>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel1_row0" class="row_heading level1 row0" >Oathbreaker, Last Hope of the Breaking Storm</th>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow0_col0" class="data row0 col0" >12</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow0_col1" class="data row0 col1" >$4.23</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow0_col2" class="data row0 col2" >$50.76</td>
#             </tr>
#             <tr>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel0_row1" class="row_heading level0 row1" >82</th>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel1_row1" class="row_heading level1 row1" >Nirvana</th>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow1_col0" class="data row1 col0" >9</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow1_col1" class="data row1 col1" >$4.90</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow1_col2" class="data row1 col2" >$44.10</td>
#             </tr>
#             <tr>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel0_row2" class="row_heading level0 row2" >145</th>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel1_row2" class="row_heading level1 row2" >Fiery Glass Crusader</th>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow2_col0" class="data row2 col0" >9</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow2_col1" class="data row2 col1" >$4.58</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow2_col2" class="data row2 col2" >$41.22</td>
#             </tr>
#             <tr>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel0_row3" class="row_heading level0 row3" >92</th>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel1_row3" class="row_heading level1 row3" >Final Critic</th>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow3_col0" class="data row3 col0" >8</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow3_col1" class="data row3 col1" >$4.88</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow3_col2" class="data row3 col2" >$39.04</td>
#             </tr>
#             <tr>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel0_row4" class="row_heading level0 row4" >103</th>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel1_row4" class="row_heading level1 row4" >Singed Scalpel</th>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow4_col0" class="data row4 col0" >8</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow4_col1" class="data row4 col1" >$4.35</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow4_col2" class="data row4 col2" >$34.80</td>
#             </tr>
#             <tr>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel0_row5" class="row_heading level0 row5" >59</th>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel1_row5" class="row_heading level1 row5" >Lightning, Etcher of the King</th>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow5_col0" class="data row5 col0" >8</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow5_col1" class="data row5 col1" >$4.23</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow5_col2" class="data row5 col2" >$33.84</td>
#             </tr>
#             <tr>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel0_row6" class="row_heading level0 row6" >108</th>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel1_row6" class="row_heading level1 row6" >Extraction, Quickblade Of Trembling Hands</th>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow6_col0" class="data row6 col0" >9</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow6_col1" class="data row6 col1" >$3.53</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow6_col2" class="data row6 col2" >$31.77</td>
#             </tr>
#             <tr>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel0_row7" class="row_heading level0 row7" >78</th>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel1_row7" class="row_heading level1 row7" >Glimmer, Ender of the Moon</th>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow7_col0" class="data row7 col0" >7</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow7_col1" class="data row7 col1" >$4.40</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow7_col2" class="data row7 col2" >$30.80</td>
#             </tr>
#             <tr>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel0_row8" class="row_heading level0 row8" >72</th>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel1_row8" class="row_heading level1 row8" >Winter's Bite</th>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow8_col0" class="data row8 col0" >8</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow8_col1" class="data row8 col1" >$3.77</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow8_col2" class="data row8 col2" >$30.16</td>
#             </tr>
#             <tr>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel0_row9" class="row_heading level0 row9" >60</th>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel1_row9" class="row_heading level1 row9" >Wolf</th>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow9_col0" class="data row9 col0" >8</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow9_col1" class="data row9 col1" >$3.54</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow9_col2" class="data row9 col2" >$28.32</td>
#             </tr>
#             <tr>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel0_row10" class="row_heading level0 row10" >179</th>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel1_row10" class="row_heading level1 row10" >Wolf, Promise of the Moonwalker</th>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow10_col0" class="data row10 col0" >6</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow10_col1" class="data row10 col1" >$4.48</td>
#                         <td id="T_f44f5ca4_7083_11ea_83ca_3cf01176596brow10_col2" class="data row10 col2" >$26.88</td>
#             </tr>
#             <tr>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel0_row11" class="row_heading level0 row11" >160</th>
#                         <th id="T_f44f5ca4_7083_11ea_83ca_3cf01176596blevel1_row11" class="row_headin

# %%
most_profitable_items_df.head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 92      Final Critic                                               8
# 103     Singed Scalpel                                             8
#
#                                                       Item Price  \
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm        4.23
# 82      Nirvana                                             4.90
# 145     Fiery Glass Crusader                                4.58
# 92      Final Critic                                        4.88
# 103     Singed Scalpel                                      4.35
#
#                                                       Total Purchase Value
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm                 50.76
# 82      Nirvana                                                      44.10
# 145     Fiery Glass Crusader                                         41.22
# 92      Final Critic                                                 39.04
# 103     Singed Scalpel                                               34.80
